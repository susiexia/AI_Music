# %%
# Import all dependencies
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav
from scipy.fftpack import fft
import numpy as np
import pandas as pd
from config import awsS3_key
# boto3 is a module to read data from S3 bucket in python.  
# You need to install it using (pip3 install boto3)
import boto3

# %%
# Connect to the S3 bucket by security credential (accesskeys)
client = boto3.client(
    's3',
    aws_access_key_id= 'AKIAIU2MIGCN6TKOZVBA',
    aws_secret_access_key= awsS3_key
)

# Use the paginator funtion to go access through the folder and files in the S3 bucket
paginator = client.get_paginator('list_objects')
result = paginator.paginate(Bucket='musicalinstrumentsaudiodataset')

# Create an empty list to add in it the list of path for the .wav files from the S3 bucket 
keylist=[]

# Create for loop to go through all the .wav files path in the folders and add them to keylist list we created.
for page in result:
    if "Contents" in page:
        for key in page[ "Contents" ]:
            keyString = key[ "Key" ]
            #print(keyString)
            keylist.append(keyString)

# %%
# Delete DS_Store files from keylist
s3FilePaths = [x for x in keylist if "DS_Store" not in x]

# %%
type(s3FilePaths)
len(s3FilePaths)
print(s3FilePaths[3])

# open the .wav files and save them as bytes 
from scipy.io import wavfile as wav
from scipy.fftpack import fft
s3 = boto3.resource('s3', aws_access_key_id= 'AKIAIU2MIGCN6TKOZVBA',
    aws_secret_access_key= awsS3_key)
bucket = s3.Bucket('musicalinstrumentsaudiodataset')

# Create an empty list to add the open .wav files in. 
wav_list=[]

# Create for loop to loop through the s3FilePaths created previously in order to read the .wavfiles and save them as bytes files in the body1 list created 
# For Ruberic 1, We will just run through the a sample of data (first 6 .wavfiles) 
for j in range(6):
    obj = s3.Object('musicalinstrumentsaudiodataset', s3FilePaths[j])
    
    # Read the .wav file
    body = obj.get()['Body'].read()
    
    # Append the file read in the body1 list. The file type is bytes.
    wav_list.append(body)
# Out:
# TinySOL/Brass/Bass_Tuba/ordinario/BTb-ord-A#2-ff-N-T19u.wav

# %%
# Create list that stores local file paths (lets save Heba some money)
localFilePaths = ["../Resources/AudioFiles/" + x for x in s3FilePaths]

# %%
# Create dataframe for file paths. One column will be used to access the remote (S3) files, the other column will be used to access local files.
filepath_df = pd.DataFrame(list(zip(wav_list, localFilePaths)), columns = ["S3 file path", "Local file path"])

# %%
filepath_df
# Out:
#                                         S3 file path  \
# 0  b'RIFF\xec\xf0\x01\x00WAVEfmt \x10\x00\x00\x00...
# 1  b'RIFF\xca\\\x04\x00WAVEfmt \x10\x00\x00\x00\x...
# 2  b'RIFF\x04\xab\x04\x00WAVEfmt \x10\x00\x00\x00...
# 3  b'RIFFx\x11\x02\x00WAVEfmt \x10\x00\x00\x00\x0...
# 4  b'RIFF\x108\x05\x00WAVEfmt \x10\x00\x00\x00\x0...
# 5  b'RIFF\x1aC\x04\x00WAVEfmt \x10\x00\x00\x00\x0...
#
#                                      Local file path
# 0  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 1  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 2  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 3  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 4  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 5  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...

# %%
# Import wav file analysis dependencies
import os
import librosa
import librosa.display
import struct

# %%
# File path troubleshooting script (comment this out if not troubleshooting)
file_name = filepath_df.loc[5,"Local file path"]
file_name
# Out:
# '../Resources/AudioFiles/TinySOL/Brass/Bass_Tuba/ordinario/BTb-ord-A#2-pp-N-N.wav'

# %%
# Test making a spectrogram with one sample (comment this out if not troubleshooting)

audio, sample_rate = librosa.load(file_name, offset=0, duration=1, res_type='kaiser_fast')
mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=50, fmax=5000)
librosa.display.specshow(librosa.power_to_db(mfccs, ref=np.max))

# %%
# Doing it using the S3 .wav file bucket and local directory
import soundfile as sf
import io

from six.moves.urllib.request import urlopen
#from urllib2 import urlopen

data, samplerate = sf.read(io.BytesIO(wav_list[1]))
mfccs = librosa.feature.mfcc(y=data, sr=samplerate, n_mfcc=50, fmax=5000)
librosa.display.specshow(librosa.power_to_db(mfccs, ref=np.max))

# %% [markdown]
# # EXTRACT & TRANSFORM

# %%
import soundfile as sf
import io
# Function that creates spectrogram
def createSpectrogram(file_name):
   
    try:
        # Using librosa automatically converts all sampling rate to 22.05KHz, normalize the bit-depth (-1 to 1), and flatten
        # audio channels into 1 channel.
        audio, sample_rate = sf.read(io.BytesIO(file_name)) # This line will use it for the S3 files
        #audio, sample_rate = librosa.load(file_name, offset=0, duration=1, res_type='kaiser_fast') # This line for the local files.

        # Convert to Mel-Frequency Cepstral Coefficients (MFCC) Spectrogram (this type of spectrogram tries to recreate how
        # humans interpret sounds)
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=50, fmax=5000)
        
        # mfccsDf = pd.DataFrame(mfccs)

    except:
        # Print this message when loading a sound file fails
        print("Create spectrogram failure:", file_name)
        return None 
     
    # Return spectrogram
    return mfccs

# %%
# Test createSpectrogram function (comment this out if not troubleshooting)
createSpectrogram(filepath_df.loc[5,"S3 file path"])
# Out:
# array([[-6.5176227e+02, -6.8041632e+02, -7.4290662e+02, ...,
#         -8.7124030e+02, -8.7775671e+02, -8.9695184e+02],
#        [ 2.4674791e+02,  2.2834918e+02,  1.9173611e+02, ...,
#          6.9095619e+01,  6.0205536e+01,  3.9516678e+01],
#        [ 2.3344515e+01,  4.4808525e+01,  9.1024895e+01, ...,
#          5.8624969e+01,  5.0152740e+01,  4.1811905e+01],
#        ...,
#        [ 8.1929779e+00,  5.0736260e+00,  1.0383249e+01, ...,
#          9.7214823e+00,  1.2072078e+01,  5.7766089e+00],
#        [ 8.2255783e+00,  7.2933440e+00,  9.7904282e+00, ...,
#          3.9994395e+00,  7.3095374e+00,  3.7336712e+00],
#        [-1.6552203e+00,  2.7454610e+00,  4.9498267e+00, ...,
#          2.1434355e+00,  3.2733765e-01,  1.2801023e+00]], dtype=float32)

# %%
# Loop through file path dataframe to run each file through createSuctrogram function

spectrograms = []

for i in range(len(filepath_df)):

    # Save file path to be ran through spectrogram function
    file_name = filepath_df.loc[i,"S3 file path"]
    
    # Run sound file through spectrogram function
    data = createSpectrogram(file_name)
    
    # Save spectrograms to array
    spectrograms.append([data])

# %%
# Convert spectrograms into a dataframe and add notes
# someone needs to merge notes into this df (use filPathsDf)
notesDf = pd.DataFrame(spectrograms, columns=['Spectrogram'])

# %%
notesDf
# Out:
#                                          Spectrogram
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
# 5  [[-651.76227, -680.4163, -742.9066, -737.35077...

# %%
filepath_df
# Out:
#                                         S3 file path  \
# 0  b'RIFF\xec\xf0\x01\x00WAVEfmt \x10\x00\x00\x00...
# 1  b'RIFF\xca\\\x04\x00WAVEfmt \x10\x00\x00\x00\x...
# 2  b'RIFF\x04\xab\x04\x00WAVEfmt \x10\x00\x00\x00...
# 3  b'RIFFx\x11\x02\x00WAVEfmt \x10\x00\x00\x00\x0...
# 4  b'RIFF\x108\x05\x00WAVEfmt \x10\x00\x00\x00\x0...
# 5  b'RIFF\x1aC\x04\x00WAVEfmt \x10\x00\x00\x00\x0...
#
#                                      Local file path
# 0  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 1  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 2  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 3  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 4  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 5  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...

# %%
# Create a dataframe for the Tiny_SOLmetadata.csv file 
tiny_soldf = pd.read_csv('../Data/TinySOL_metadata.csv')

# %%
# Get a sample of the metadata dataframe (First 7 rows) to match the filepth_df we created and for Rubric 1 purposes
tiny_soldf_sample =pd.DataFrame(tiny_soldf[0:6])

# %%
# Merge the metadata datafframe with the filepath_df on the index
df_merge_col = pd.merge(filepath_df, tiny_soldf_sample, right_index=True, left_index=True)
df_merge_col
# Out:
#                                         S3 file path  \
# 0  b'RIFF\xec\xf0\x01\x00WAVEfmt \x10\x00\x00\x00...
# 1  b'RIFF\xca\\\x04\x00WAVEfmt \x10\x00\x00\x00\x...
# 2  b'RIFF\x04\xab\x04\x00WAVEfmt \x10\x00\x00\x00...
# 3  b'RIFFx\x11\x02\x00WAVEfmt \x10\x00\x00\x00\x0...
# 4  b'RIFF\x108\x05\x00WAVEfmt \x10\x00\x00\x00\x0...
# 5  b'RIFF\x1aC\x04\x00WAVEfmt \x10\x00\x00\x00\x0...
#
#                                    Local file path_x  \
# 0  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 1  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 2  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 3  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 4  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 5  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
#
#                                    Local file path_y  Fold Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav     2  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...     4  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...     3  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...     2  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav     0  Brass
# 5    Brass/Bass_Tuba/ordinario/BTb-ord-B1-pp-N-N.wav     1  Brass
#
#   Instrument (abbr.) Instrument (in full) Technique (abbr.)  \
# 0                BTb            Bass Tuba               ord
# 1                BTb            Bass Tuba               ord
# 2                BTb            Bass Tuba               ord
# 3                BTb            Bass Tuba               ord
# 4                BTb            Bass Tuba               ord
# 5                BTb            Bass Tuba               ord
#
#   Technique (in full) Pitch  Pitch ID Dynamics  Dynamics ID  Instance ID  \
# 0           ordinario   F#1        30       pp            0            0
# 1           ordinario    G1        31       pp            0            0
# 2           ordinario   G#1        32       pp            0            0
# 3           ordinario    A1        33       pp            0            0
# 4           ordinario   A#1        34       pp            0            0
# 5           ordinario    B1        35       pp            0            0
#
#    String ID (if applicable)  Needed digital retuning
# 0                        NaN                    False
# 1                        NaN                     True
# 2                        NaN                     True
# 3                        NaN                     True
# 4                        NaN                    False
# 5                        NaN                    False

# %%
# Merge the notes spectrogram with the merged dataframe that contains the filepath_df and metada dataframe
notesDf_merged = pd.merge(notesDf, df_merge_col, right_index=True, left_index=True)
notesDf_merged
# Out:
#                                          Spectrogram  \
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
# 5  [[-651.76227, -680.4163, -742.9066, -737.35077...
#
#                                         S3 file path  \
# 0  b'RIFF\xec\xf0\x01\x00WAVEfmt \x10\x00\x00\x00...
# 1  b'RIFF\xca\\\x04\x00WAVEfmt \x10\x00\x00\x00\x...
# 2  b'RIFF\x04\xab\x04\x00WAVEfmt \x10\x00\x00\x00...
# 3  b'RIFFx\x11\x02\x00WAVEfmt \x10\x00\x00\x00\x0...
# 4  b'RIFF\x108\x05\x00WAVEfmt \x10\x00\x00\x00\x0...
# 5  b'RIFF\x1aC\x04\x00WAVEfmt \x10\x00\x00\x00\x0...
#
#                                    Local file path_x  \
# 0  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 1  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 2  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 3  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 4  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
# 5  ../Resources/AudioFiles/TinySOL/Brass/Bass_Tub...
#
#                                    Local file path_y  Fold Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav     2  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...     4  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...     3  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...     2  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav     0  Brass
# 5    Brass/Bass_Tuba/ordinario/BTb-ord-B1-pp-N-N.wav     1  Brass
#
#   Instrument (abbr.) Instrument (in full) Technique (abbr.)  \
# 0                BTb            Bass Tuba               ord
# 1                BTb            Bass Tuba               ord
# 2                BTb            Bass Tuba               ord
# 3                BTb            Bass Tuba               ord
# 4                BTb            Bass Tuba               ord
# 5                BTb            Bass Tuba               ord
#
#   Technique (in full) Pitch  Pitch ID Dynamics  Dynamics ID  Instance ID  \
# 0           ordinario   F#1        30       pp            0            0
# 1           ordinario    G1        31       pp            0            0
# 2           ordinario   G#1        32       pp            0            0
# 3           ordinario    A1        33       pp            0            0
# 4           ordinario   A#1        34       pp            0            0
# 5           ordinario    B1        35       pp            0            0
#
#    String ID (if applicable)  Needed digital retuning
# 0                        NaN                    False
# 1                        NaN                     True
# 2                        NaN                     True
# 3                        NaN                     True
# 4                        NaN                    False
# 5                        NaN                    False

# %%
# Delete the unecessary columns
notesDF_Final = notesDf_merged.drop(['S3 file path', 'Local file path_x','Fold','Family','Instrument (abbr.)', 'Instrument (in full)','Technique (abbr.)', 'Technique (in full)','Dynamics','Dynamics ID',	'Instance ID', 'String ID (if applicable)','Needed digital retuning'], axis=1)

# %%
notesDF_Final
# Out:
#                                          Spectrogram  \
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
# 5  [[-651.76227, -680.4163, -742.9066, -737.35077...
#
#                                    Local file path_y Pitch  Pitch ID
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav   F#1        30
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...    G1        31
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...   G#1        32
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...    A1        33
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav   A#1        34
# 5    Brass/Bass_Tuba/ordinario/BTb-ord-B1-pp-N-N.wav    B1        35

# %%
# Save it to a csv file
notesDF_Final.to_csv('../Data/notesdf.csv')

# %%
# Create a dataframe that has the spectrogram with the instrument
Instrument_DF_Final = notesDf_merged.drop(['S3 file path', 'Local file path_x','Fold','Technique (abbr.)', 'Technique (in full)','Dynamics','Dynamics ID','Instance ID', 'String ID (if applicable)','Needed digital retuning','Pitch','Pitch ID'], axis=1)

# %%
Instrument_DF_Final
# Out:
#                                          Spectrogram  \
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
# 5  [[-651.76227, -680.4163, -742.9066, -737.35077...
#
#                                    Local file path_y Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav  Brass
# 5    Brass/Bass_Tuba/ordinario/BTb-ord-B1-pp-N-N.wav  Brass
#
#   Instrument (abbr.) Instrument (in full)
# 0                BTb            Bass Tuba
# 1                BTb            Bass Tuba
# 2                BTb            Bass Tuba
# 3                BTb            Bass Tuba
# 4                BTb            Bass Tuba
# 5                BTb            Bass Tuba

# %%
# Save it to a csv file(Check with you first)
#Instrument_DF_Final.to_csv('/../../AI_Music/Data/notesdf.csv')

# %%
# Create a dataframe that has spectrogram, note, and instrument
Instrument_notes_DF_Final = notesDf_merged.drop(['S3 file path', 'Local file path_x','Fold','Technique (abbr.)', 'Technique (in full)','Dynamics','Dynamics ID',	'Instance ID', 'String ID (if applicable)','Needed digital retuning'], axis=1)

# %%
Instrument_notes_DF_Final
# Out:
#                                          Spectrogram  \
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
# 5  [[-651.76227, -680.4163, -742.9066, -737.35077...
#
#                                    Local file path_y Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav  Brass
# 5    Brass/Bass_Tuba/ordinario/BTb-ord-B1-pp-N-N.wav  Brass
#
#   Instrument (abbr.) Instrument (in full) Pitch  Pitch ID
# 0                BTb            Bass Tuba   F#1        30
# 1                BTb            Bass Tuba    G1        31
# 2                BTb            Bass Tuba   G#1        32
# 3                BTb            Bass Tuba    A1        33
# 4                BTb            Bass Tuba   A#1        34
# 5                BTb            Bass Tuba    B1        35

# %%
# Save it to a csv file(Check with you first)
#Instrument_notes_DF_Final.to_csv('/Users/hebamaly/AI_Music/Data/notesdf.csv')

# %% [markdown]
# # Load

# %%
# This is the code to upload the dataframe into the postgres as a table 
#from sqlalchemy import create_engine
#engine = create_engine('postgresql://username:password@host:port/database')
#notesDF_Final.to_sql('table_name', engine)

# %%
# **** Ignore this *****
#!pip install -q findspark
#!wget https://jdbc.postgresql.org/download/postgresql-42.2.9.jar
#import findspark
#findspark.init()
#from pyspark.sql import SparkSession
#mode = "append"
#jdbc_url="jdbc:postgresql://dataviz.c9m6p9myd7tx.us-east-2.rds.amazonaws.com:5432/reviewdataset_Mod16_Challenge"
#config = {"user":"postgres",
 #         "password": "mymody143",
  #        "driver":"org.postgresql.Driver"}
#url = "jdbc:postgresql://<rds_host_name>/<database_name>"
#properties = {
#"user" : "<username>",
#"password" : "<password>"
#}
#df = spark.read.jdbc(url=url, table="<schema.table>", properties=properties)
# Write DataFrame to review id table  in RDS
#rev_id_df.write.jdbc(url=jdbc_url, table='review_id_table', mode=mode, properties=config)

# %% [markdown]
# ## Model - Neural Network

# %%
# Change category into numerical columns

# %%
# imports
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
Instrument_notes_DF_Final["Pitch"] = Instrument_notes_DF_Final["Pitch"].astype('category')
Instrument_notes_DF_Final["Instrument (in full)"] = Instrument_notes_DF_Final["Instrument (in full)"].astype('category')

# Since this is a model/draft, I will be "numerically" naming the spectrogram because no spectrogram is going to have the same values
spec = [0, 1, 2, 3, 4, 5]
Instrument_notes_DF_Final["Spectrogram_cat"] = spec

# %%
Instrument_notes_DF_Final.astype
# Out:
# <bound method NDFrame.astype of                                          Spectrogram  \
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
# 5  [[-651.76227, -680.4163, -742.9066, -737.35077...
#
#                                    Local file path_y Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav  Brass
# 5    Brass/Bass_Tuba/ordinario/BTb-ord-B1-pp-N-N.wav  Brass
#
#   Instrument (abbr.) Instrument (in full) Pitch  Pitch ID  Spectrogram_cat
# 0                BTb            Bass Tuba   F#1        30                0
# 1                BTb            Bass Tuba    G1        31                1
# 2                BTb            Bass Tuba   G#1        32                2
# 3                BTb            Bass Tuba    A1        33                3
# 4                BTb            Bass Tuba   A#1        34                4
# 5                BTb            Bass Tuba    B1        35                5  >

# %%
Instrument_notes_DF_Final["Pitch_cat"] = Instrument_notes_DF_Final["Pitch"].cat.codes
Instrument_notes_DF_Final["Instrument_cat"] = Instrument_notes_DF_Final["Instrument (in full)"].cat.codes

# %%
Instrument_notes_DF_Final.head()
# Out:
#                                          Spectrogram  \
# 0  [[-568.29565, -503.98215, -421.85892, -373.815...
# 1  [[-708.3789, -682.25964, -679.7246, -679.73236...
# 2  [[-714.0137, -717.3916, -760.54626, -776.73004...
# 3  [[-561.6063, -469.6161, -426.02832, -374.23523...
# 4  [[-672.5895, -670.18713, -634.01227, -622.8166...
#
#                                    Local file path_y Family  \
# 0   Brass/Bass_Tuba/ordinario/BTb-ord-F#1-pp-N-N.wav  Brass
# 1  Brass/Bass_Tuba/ordinario/BTb-ord-G1-pp-N-R100...  Brass
# 2  Brass/Bass_Tuba/ordinario/BTb-ord-G#1-pp-N-T16...  Brass
# 3  Brass/Bass_Tuba/ordinario/BTb-ord-A1-pp-N-T23d...  Brass
# 4   Brass/Bass_Tuba/ordinario/BTb-ord-A#1-pp-N-N.wav  Brass
#
#   Instrument (abbr.) Instrument (in full) Pitch  Pitch ID  Spectrogram_cat  \
# 0                BTb            Bass Tuba   F#1        30                0
# 1                BTb            Bass Tuba    G1        31                1
# 2                BTb            Bass Tuba   G#1        32                2
# 3                BTb            Bass Tuba    A1        33                3
# 4                BTb            Bass Tuba   A#1        34                4
#
#    Pitch_cat  Instrument_cat
# 0          3               0
# 1          5               0
# 2          4               0
# 3          1               0
# 4          0               0

# %%
instrumentDF = Instrument_notes_DF_Final[["Instrument_cat", "Pitch_cat", "Spectrogram_cat"]].copy()

# %%
# instrumentDF that will be inputted into the model - instrument, pitch, spectro
instrumentDF.head()
# Out:
#    Instrument_cat  Pitch_cat  Spectrogram_cat
# 0               0          3                0
# 1               0          5                1
# 2               0          4                2
# 3               0          1                3
# 4               0          0                4

# %%
# create notesDF - notes and spectro
notesDF = Instrument_notes_DF_Final[["Pitch_cat", "Spectrogram_cat"]].copy()

# %%
notesDF
# Out:
#    Pitch_cat  Spectrogram_cat
# 0          3                0
# 1          5                1
# 2          4                2
# 3          1                3
# 4          0                4
# 5          2                5

# %%
y = instrumentDF.Instrument_cat
X = instrumentDF.drop(columns="Instrument_cat")

# split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net
number_input_features = 2
hidden_nodes_layer1 =  3
hidden_nodes_layer2 = 1

# Number of layers and nodes will depend how many features we have in total (including the image features)

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 4
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
len(X_train)
# Out:
# 4

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Train on 4 samples
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6877 - accuracy: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s 764us/sample - loss: 0.6872 - accuracy: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6867 - accuracy: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s 735us/sample - loss: 0.6862 - accuracy: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s 988us/sample - loss: 0.6857 - accuracy: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s 731us/sample - loss: 0.6852 - accuracy: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6847 - accuracy: 1.0000
# Epoch 8/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6842 - accuracy: 1.0000
# Epoch 9/100
# 4/4 [==============================] - 0s 757us/sample - loss: 0.6837 - accuracy: 1.0000
# Epoch 10/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6832 - accuracy: 1.0000
# Epoch 11/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6827 - accuracy: 1.0000
# Epoch 12/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6822 - accuracy: 1.0000
# Epoch 13/100
# 4/4 [==============================] - 0s 545us/sample - loss: 0.6817 - accuracy: 1.0000
# Epoch 14/100
# 4/4 [==============================] - 0s 993us/sample - loss: 0.6812 - accuracy: 1.0000
# Epoch 15/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6807 - accuracy: 1.0000
# Epoch 16/100
# 4/4 [==============================] - 0s 972us/sample - loss: 0.6802 - accuracy: 1.0000
# Epoch 17/100
# 4/4 [==============================] - 0s 757us/sample - loss: 0.6798 - accuracy: 1.0000
# Epoch 18/100
# 4/4 [==============================] - 0s 984us/sample - loss: 0.6793 - accuracy: 1.0000
# Epoch 19/100
# 4/4 [==============================] - 0s 725us/sample - loss: 0.6788 - accuracy: 1.0000
# Epoch 20/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6783 - accuracy: 1.0000
# Epoch 21/100
# 4/4 [==============================] - 0s 730us/sample - loss: 0.6778 - accuracy: 1.0000
# Epoch 22/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6773 - accuracy: 1.0000
# Epoch 23/100
# 4/4 [==============================] - 0s 819us/sample - loss: 0.6768 - accuracy: 1.0000
# Epoch 24/100
# 4/4 [==============================] - 0s 749us/sample - loss: 0.6763 - accuracy: 1.0000
# Epoch 25/100
# 4/4 [==============================] - 0s 753us/sample - loss: 0.6758 - accuracy: 1.0000
# Epoch 26/100
# 4/4 [==============================] - 0s 738us/sample - loss: 0.6753 - accuracy: 1.0000
# Epoch 27/100
# 4/4 [==============================] - 0s 999us/sample - loss: 0.6749 - accuracy: 1.0000
# Epoch 28/100
# 4/4 [==============================] - 0s 762us/sample - loss: 0.6744 - accuracy: 1.0000
# Epoch 29/100
# 4/4 [==============================] - 0s 741us/sample - loss: 0.6739 - accuracy: 1.0000
# Epoch 30/100
# 4/4 [==============================] - 0s 684us/sample - loss: 0.6734 - accuracy: 1.0000
# Epoch 31/100
# 4/4 [==============================] - 0s 653us/sample - loss: 0.6729 - accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6724 - accuracy: 1.0000
# Epoch 33/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6719 - accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 0s 693us/sample - loss: 0.6714 - accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6710 - accuracy: 1.0000
# Epoch 36/100
# 4/4 [==============================] - 0s 994us/sample - loss: 0.6705 - accuracy: 1.0000
# Epoch 37/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6700 - accuracy: 1.0000
# Epoch 38/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6695 - accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6690 - accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6685 - accuracy: 1.0000
# Epoch 41/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6680 - accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6676 - accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6671 - accuracy: 1.0000
# Epoch 44/100
# 4/4 [==============================] - 0s 943us/sample - loss: 0.6666 - accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 0s 960us/sample - loss: 0.6661 - accuracy: 1.0000
# Epoch 46/100
# 4/4 [==============================] - 0s 764us/sample - loss: 0.6656 - accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6652 - accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6647 - accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6642 - accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 0s 772us/sample - loss: 0.6637 - accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6632 - accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 0s 749us/sample - loss: 0.6628 - accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6623 - accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 0s 992us/sample - loss: 0.6618 - accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 0s 753us/sample - loss: 0.6613 - accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6608 - accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6604 - accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 0s 745us/sample - loss: 0.6599 - accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6594 - accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6589 - accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6585 - accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6580 - accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 0s 742us/sample - loss: 0.6575 - accuracy: 1.0000
# Epoch 64/100
# 4/4 [==============================] - 0s 757us/sample - loss: 0.6570 - accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6566 - accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 0s 795us/sample - loss: 0.6561 - accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.6556 - accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 0s 487us/sample - loss: 0.6551 - accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 0s 756us/sample - loss: 0.6547 - accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6542 - accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6537 - accuracy: 1.0000
# Epoch 72/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6532 - accuracy: 1.0000
# Epoch 73/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6528 - accuracy: 1.0000
# Epoch 74/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6523 - accuracy: 1.0000
# Epoch 75/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6518 - accuracy: 1.0000
# Epoch 76/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6514 - accuracy: 1.0000
# Epoch 77/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6509 - accuracy: 1.0000
# Epoch 78/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.6504 - accuracy: 1.0000
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6499 - accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6495 - accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6490 - accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 986us/sample - loss: 0.6485 - accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 999us/sample - loss: 0.6481 - accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6476 - accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6471 - accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6467 - accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6462 - accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6457 - accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6453 - accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6448 - accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6443 - accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6439 - accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6434 - accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6429 - accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 753us/sample - loss: 0.6425 - accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 992us/sample - loss: 0.6420 - accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6416 - accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6411 - accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6406 - accuracy: 1.0000
# Epoch 100/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6402 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2/2 - 0s - loss: 0.6877 - accuracy: 1.0000
# Loss: 0.6876633763313293, Accuracy: 1.0

# %%
# Neural network

# %%
y2 = notesDF.Pitch_cat
X2 = notesDF.drop(columns="Pitch_cat")

# %%
# split dataset
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, random_state=78)

# %%
# Create scaler instance
X_scaler2 = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler2.fit(X_train2)

# Scale the data
X_train_scaled2 = X_scaler2.transform(X_train2)
X_test_scaled2 = X_scaler2.transform(X_test2)

# %%
# Define the model - deep neural net
number_input_features2 = 1
hidden_nodes_layer1_2 =  1
hidden_nodes_layer2_2= 1

# Number of layers and nodes will depend how many features we have in total (including the image features)

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1_2, input_dim=number_input_features2, activation="relu")
)

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2_2, activation="relu"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_37 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model2 = nn2.fit(X_train2,y_train2,epochs=100)
# Out:
# Train on 4 samples
# Epoch 1/100
# 4/4 [==============================] - 1s 226ms/sample - loss: 0.6931 - accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6901 - accuracy: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s 761us/sample - loss: 0.6871 - accuracy: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s 987us/sample - loss: 0.6841 - accuracy: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s 725us/sample - loss: 0.6811 - accuracy: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s 498us/sample - loss: 0.6782 - accuracy: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s 755us/sample - loss: 0.6752 - accuracy: 0.0000e+00
# Epoch 8/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6722 - accuracy: 0.0000e+00
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6692 - accuracy: 0.0000e+00
# Epoch 10/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6662 - accuracy: 0.0000e+00
# Epoch 11/100
# 4/4 [==============================] - 0s 749us/sample - loss: 0.6632 - accuracy: 0.0000e+00
# Epoch 12/100
# 4/4 [==============================] - 0s 747us/sample - loss: 0.6602 - accuracy: 0.0000e+00
# Epoch 13/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6572 - accuracy: 0.0000e+00
# Epoch 14/100
# 4/4 [==============================] - 0s 910us/sample - loss: 0.6542 - accuracy: 0.0000e+00
# Epoch 15/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.6512 - accuracy: 0.0000e+00
# Epoch 16/100
# 4/4 [==============================] - 0s 844us/sample - loss: 0.6482 - accuracy: 0.0000e+00
# Epoch 17/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6452 - accuracy: 0.0000e+00
# Epoch 18/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6422 - accuracy: 0.0000e+00
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6392 - accuracy: 0.0000e+00
# Epoch 20/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6362 - accuracy: 0.0000e+00
# Epoch 21/100
# 4/4 [==============================] - 0s 957us/sample - loss: 0.6332 - accuracy: 0.0000e+00
# Epoch 22/100
# 4/4 [==============================] - 0s 989us/sample - loss: 0.6302 - accuracy: 0.0000e+00
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6272 - accuracy: 0.0000e+00
# Epoch 24/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6242 - accuracy: 0.0000e+00
# Epoch 25/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6212 - accuracy: 0.0000e+00
# Epoch 26/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6182 - accuracy: 0.0000e+00
# Epoch 27/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6152 - accuracy: 0.0000e+00
# Epoch 28/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.6123 - accuracy: 0.0000e+00
# Epoch 29/100
# 4/4 [==============================] - 0s 779us/sample - loss: 0.6093 - accuracy: 0.0000e+00
# Epoch 30/100
# 4/4 [==============================] - 0s 988us/sample - loss: 0.6063 - accuracy: 0.0000e+00
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.6033 - accuracy: 0.0000e+00
# Epoch 32/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.6003 - accuracy: 0.0000e+00
# Epoch 33/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.5973 - accuracy: 0.0000e+00
# Epoch 34/100
# 4/4 [==============================] - 0s 754us/sample - loss: 0.5943 - accuracy: 0.0000e+00
# Epoch 35/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.5913 - accuracy: 0.0000e+00
# Epoch 36/100
# 4/4 [==============================] - 0s 836us/sample - loss: 0.5883 - accuracy: 0.0000e+00
# Epoch 37/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.5853 - accuracy: 0.0000e+00
# Epoch 38/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.5824 - accuracy: 0.0000e+00
# Epoch 39/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.5794 - accuracy: 0.0000e+00
# Epoch 40/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.5764 - accuracy: 0.0000e+00
# Epoch 41/100
# 4/4 [==============================] - 0s 959us/sample - loss: 0.5734 - accuracy: 0.0000e+00
# Epoch 42/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.5704 - accuracy: 0.0000e+00
# Epoch 43/100
# 4/4 [==============================] - 0s 754us/sample - loss: 0.5674 - accuracy: 0.0000e+00
# Epoch 44/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.5644 - accuracy: 0.0000e+00
# Epoch 45/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.5614 - accuracy: 0.0000e+00
# Epoch 46/100
# 4/4 [==============================] - 0s 686us/sample - loss: 0.5585 - accuracy: 0.0000e+00
# Epoch 47/100
# 4/4 [==============================] - 0s 667us/sample - loss: 0.5555 - accuracy: 0.0000e+00
# Epoch 48/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.5525 - accuracy: 0.0000e+00
# Epoch 49/100
# 4/4 [==============================] - 0s 745us/sample - loss: 0.5495 - accuracy: 0.0000e+00
# Epoch 50/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.5465 - accuracy: 0.0000e+00
# Epoch 51/100
# 4/4 [==============================] - 0s 787us/sample - loss: 0.5435 - accuracy: 0.0000e+00
# Epoch 52/100
# 4/4 [==============================] - 0s 757us/sample - loss: 0.5406 - accuracy: 0.0000e+00
# Epoch 53/100
# 4/4 [==============================] - 0s 572us/sample - loss: 0.5376 - accuracy: 0.0000e+00
# Epoch 54/100
# 4/4 [==============================] - 0s 504us/sample - loss: 0.5346 - accuracy: 0.0000e+00
# Epoch 55/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.5316 - accuracy: 0.0000e+00
# Epoch 56/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.5286 - accuracy: 0.0000e+00
# Epoch 57/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.5256 - accuracy: 0.0000e+00
# Epoch 58/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.5227 - accuracy: 0.0000e+00
# Epoch 59/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.5197 - accuracy: 0.0000e+00
# Epoch 60/100
# 4/4 [==============================] - 0s 744us/sample - loss: 0.5167 - accuracy: 0.0000e+00
# Epoch 61/100
# 4/4 [==============================] - 0s 753us/sample - loss: 0.5137 - accuracy: 0.0000e+00
# Epoch 62/100
# 4/4 [==============================] - 0s 737us/sample - loss: 0.5107 - accuracy: 0.0000e+00
# Epoch 63/100
# 4/4 [==============================] - 0s 753us/sample - loss: 0.5078 - accuracy: 0.0000e+00
# Epoch 64/100
# 4/4 [==============================] - 0s 754us/sample - loss: 0.5048 - accuracy: 0.0000e+00
# Epoch 65/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.5018 - accuracy: 0.0000e+00
# Epoch 66/100
# 4/4 [==============================] - 0s 722us/sample - loss: 0.4988 - accuracy: 0.0000e+00
# Epoch 67/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.4958 - accuracy: 0.0000e+00
# Epoch 68/100
# 4/4 [==============================] - 0s 985us/sample - loss: 0.4929 - accuracy: 0.0000e+00
# Epoch 69/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.4899 - accuracy: 0.0000e+00
# Epoch 70/100
# 4/4 [==============================] - 0s 504us/sample - loss: 0.4869 - accuracy: 0.0000e+00
# Epoch 71/100
# 4/4 [==============================] - 0s 737us/sample - loss: 0.4839 - accuracy: 0.0000e+00
# Epoch 72/100
# 4/4 [==============================] - 0s 632us/sample - loss: 0.4810 - accuracy: 0.0000e+00
# Epoch 73/100
# 4/4 [==============================] - 0s 646us/sample - loss: 0.4780 - accuracy: 0.0000e+00
# Epoch 74/100
# 4/4 [==============================] - 0s 632us/sample - loss: 0.4750 - accuracy: 0.0000e+00
# Epoch 75/100
# 4/4 [==============================] - 0s 997us/sample - loss: 0.4720 - accuracy: 0.0000e+00
# Epoch 76/100
# 4/4 [==============================] - 0s 998us/sample - loss: 0.4691 - accuracy: 0.0000e+00
# Epoch 77/100
# 4/4 [==============================] - 0s 738us/sample - loss: 0.4661 - accuracy: 0.0000e+00
# Epoch 78/100
# 4/4 [==============================] - 0s 817us/sample - loss: 0.4631 - accuracy: 0.0000e+00
# Epoch 79/100
# 4/4 [==============================] - 0s 730us/sample - loss: 0.4601 - accuracy: 0.0000e+00
# Epoch 80/100
# 4/4 [==============================] - 0s 736us/sample - loss: 0.4572 - accuracy: 0.0000e+00
# Epoch 81/100
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.4542 - accuracy: 0.0000e+00
# Epoch 82/100
# 4/4 [==============================] - 0s 746us/sample - loss: 0.4512 - accuracy: 0.0000e+00
# Epoch 83/100
# 4/4 [==============================] - 0s 887us/sample - loss: 0.4482 - accuracy: 0.0000e+00
# Epoch 84/100
# 4/4 [==============================] - 0s 499us/sample - loss: 0.4453 - accuracy: 0.0000e+00
# Epoch 85/100
# 4/4 [==============================] - 0s 757us/sample - loss: 0.4423 - accuracy: 0.0000e+00
# Epoch 86/100
# 4/4 [==============================] - 0s 744us/sample - loss: 0.4393 - accuracy: 0.0000e+00
# Epoch 87/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.4364 - accuracy: 0.0000e+00
# Epoch 88/100
# 4/4 [==============================] - 0s 753us/sample - loss: 0.4334 - accuracy: 0.0000e+00
# Epoch 89/100
# 4/4 [==============================] - 0s 769us/sample - loss: 0.4304 - accuracy: 0.0000e+00
# Epoch 90/100
# 4/4 [==============================] - 0s 728us/sample - loss: 0.4275 - accuracy: 0.0000e+00
# Epoch 91/100
# 4/4 [==============================] - 0s 760us/sample - loss: 0.4245 - accuracy: 0.0000e+00
# Epoch 92/100
# 4/4 [==============================] - 0s 725us/sample - loss: 0.4215 - accuracy: 0.0000e+00
# Epoch 93/100
# 4/4 [==============================] - 0s 944us/sample - loss: 0.4185 - accuracy: 0.0000e+00
# Epoch 94/100
# 4/4 [==============================] - 0s 508us/sample - loss: 0.4156 - accuracy: 0.0000e+00
# Epoch 95/100
# 4/4 [==============================] - 0s 942us/sample - loss: 0.4126 - accuracy: 0.0000e+00
# Epoch 96/100
# 4/4 [==============================] - 0s 748us/sample - loss: 0.4096 - accuracy: 0.0000e+00
# Epoch 97/100
# 4/4 [==============================] - 0s 668us/sample - loss: 0.4067 - accuracy: 0.0000e+00
# Epoch 98/100
# 4/4 [==============================] - 0s 739us/sample - loss: 0.4037 - accuracy: 0.0000e+00
# Epoch 99/100
# 4/4 [==============================] - 0s 754us/sample - loss: 0.4007 - accuracy: 0.0000e+00
# Epoch 100/100
# 4/4 [==============================] - 0s 755us/sample - loss: 0.3978 - accuracy: 0.0000e+00

# %%
# Evaluate the model using the test data
model_loss2, model_accuracy2 = nn2.evaluate(X_test2,y_test2,verbose=2)
print(f"Loss: {model_loss2}, Accuracy: {model_accuracy2}")
# Out:
# 2/2 - 0s - loss: 0.6944 - accuracy: 0.5000
# Loss: 0.6943931579589844, Accuracy: 0.5
